# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer
from sklearn.model_selection import train_test_split
import imblearn
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report, roc_auc_score, confusion_matrix

# %%
df = pd.read_csv("superstore_data.csv")

# %%
df
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumDealsPurchases  \
# 0            0   6/16/2014        0       189  ...                  1
# 1            0   6/15/2014        0       464  ...                  1
# 2            1   5/13/2014        0       134  ...                  1
# 3            1   11/5/2014        0        10  ...                  1
# 4            0    8/4/2014        0         6  ...                  2
# ...        ...         ...      ...       ...  ...                ...
# 2235         1    7/3/2013       99       372  ...                  2
# 2236         0   1/22/2013       99         5  ...                  1
# 2237         0   3/12/2012       99       185  ...                  2
# 2238         0  11/29/2012       99       267  ...                  1
# 2239         2    1/9/2012       99       169  ...                  1
#
#       NumWebPurchases  NumCatalogPurchases  NumStorePurchases  \
# 0                   4                    4                  6
# 1                   7                    3                  7
# 2                   3                    2                  5
# 3                   1                    0                  2
# 4                   3                    1                  2
# ...               ...                  ...                ...
# 2235                5                    2                 11
# 2236                1                    0                  3
# 2237                6                    1                  5
# 2238                5                    4                 10
# 2239                8                    5                  4
#
#       NumWebVisitsMonth  Response  Complain  Age  Education_combined  \
# 0                     1         1         0   53                 Low
# 1                     5         1         0   62                 Low
# 2                     2         0         0   65                 Low
# 3                     7         0         0   56                 Low
# 4                     7         1         0   34                 Low
# ...                 ...       ...       ...  ...                 ...
# 2235                  4         0         0   47                High
# 2236                  8         0         0   46                 Low
# 2237                  8         0         0   47                 Low
# 2238                  3         0         0   45                 Low
# 2239                  7         1         0   54                High
#
#       Marital_combined
# 0             Divorced
# 1               Single
# 2              Married
# 3             Together
# 4               Single
# ...                ...
# 2235          Divorced
# 2236           Married
# 2237          Divorced
# 2238           Married
# 2239           Married
#
# [2240 rows x 25 columns]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# 1. Adjust existing features and add new ones
# 2. Handle missing values in Income field
# 3. Apply one-hot encoding to categorical variables
# 4. Split data into training and testing sets
# 5. Standardize data
# 6. Resolve class imbalance for Response target variable

# %%
#Convert birth year to customer age
df['Age'] = datetime.date.today().year - df['Year_Birth']

# %%
#Combine education levels
#Masters and PhD are High level, rest are labeled as Low
def education_transform(level):
    if level in ['PhD', 'Master']:
        return 'High'
    return 'Low'
df['Education_combined'] = df['Education'].map(education_transform)

# %%
#Combine marital status levels
#Adding Alone, YOLO, and Absurd to Single
#Combining Divorced and Widow
def marital_adjust(s):
    if s in ['Alone', 'YOLO', 'Absurd']:
        return 'Single'
    elif s in ['Widow']:
        return 'Divorced'
    else:
        return s
df['Marital_combined'] = df['Marital_Status'].map(marital_adjust)

# %%
#Adding year joined field based on Dt_Customer
#Adding number of years individual has been a customer
df['Dt_Customer'] = pd.to_datetime(df['Dt_Customer'])
df['Year_Joined'] = pd.DatetimeIndex(df["Dt_Customer"]).year
df['Years_Customer'] = datetime.date.today().year - df['Year_Joined']

# %%
#Replacing missing Income values with Iterative Imputer
imputer = IterativeImputer(random_state = 10)
df['Income'] = imputer.fit_transform(df[['Income']])
df.isna().sum()
# Out:
# Id                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# Response               0
# Complain               0
# Age                    0
# dtype: int64

# %%
#One-hot encoding for categorical variables
df = pd.get_dummies(df, columns = ['Education', 'Marital_Status'], drop_first = True)

# %%
#Split data using train/test split
X = df.drop(columns = ['Response', 'Id', 'Dt_Customer'], axis = 1)
y = df['Response']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 10, stratify = y)

# %%
#Standardize Data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
#Handle class imbalance using SMOTE
y_train.value_counts()
oversample = SMOTE()
X_train_scaled, y_train = oversample.fit_resample(X_train_scaled, y_train)

# %%
df['Response'].value_counts()
# Out:
# 0    1906
# 1     334
# Name: Response, dtype: int64

# %% [markdown]
# # Model Development

# %%
#List containing each model
model_list = []

# %%
#Logistic Regression Model
lr_model = LogisticRegression()
lr_model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
#Decision Tree Classifier
dt_model = DecisionTreeClassifier()
dt_model.fit(X_train_scaled, y_train)
# Out:
# DecisionTreeClassifier()

# %%
#Random Forest Classifier
rf_model = RandomForestClassifier()
rf_model.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier()

# %%
#KNeighbors Classifier
knn_model = KNeighborsClassifier(n_neighbors = 20)
knn_model.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %%
#Gradient Boost Classifier
import xgboost as xgb
xgb_model = xgb.XGBClassifier(objective = "binary:logistic", learning_rate = 0.05, n_estimators = 1000,
                              max_depth = 6, random_state = 42)
xgb_model.fit(X_train_scaled, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.05, max_bin=256,
#               max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#               max_depth=6, max_leaves=0, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=1000, n_jobs=0,
#               num_parallel_tree=1, predictor='auto', random_state=42, ...)

# %%
model_list = [lr_model, dt_model, rf_model, knn_model, xgb_model]

# %% [markdown]
# # GridSearch to fine-tune parameters

# %%
from sklearn.model_selection import GridSearchCV
search_param = {'max_depth': [3, 6, 10],
                'learning_rate': [.01, .05, .1, .3],
                'n_estimators': [100, 500, 1000]}
GS = GridSearchCV(estimator = xgb_model,
                 param_grid = search_param,
                 scoring = ['roc_auc', 'accuracy'],
                 refit = 'roc_auc', 
                 cv = 5,
                 verbose = 4)
GS.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=100; accuracy: (test=0.770) roc_auc: (test=0.859) total time=   0.3s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=100; accuracy: (test=0.848) roc_auc: (test=0.933) total time=   0.3s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=100; accuracy: (test=0.821) roc_auc: (test=0.913) total time=   0.4s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=100; accuracy: (test=0.869) roc_auc: (test=0.936) total time=   0.3s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=100; accuracy: (test=0.856) roc_auc: (test=0.945) total time=   0.3s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=500; accuracy: (test=0.793) roc_auc: (test=0.908) total time=   1.5s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=500; accuracy: (test=0.911) roc_auc: (test=0.979) total time=   1.4s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=500; accuracy: (test=0.895) roc_auc: (test=0.975) total time=   1.5s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=500; accuracy: (test=0.925) roc_auc: (test=0.980) total time=   1.7s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=500; accuracy: (test=0.915) roc_auc: (test=0.981) total time=   1.4s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=1000; accuracy: (test=0.774) roc_auc: (test=0.920) total time=   2.9s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=1000; accuracy: (test=0.936) roc_auc: (test=0.988) total time=   2.8s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=1000; accuracy: (test=0.933) roc_auc: (test=0.988) total time=   2.9s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=1000; accuracy: (test=0.944) roc_auc: (test=0.987) total time=   2.9s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=1000; accuracy: (test=0.928) roc_auc: (test=0.988) total time=   3.1s
# [CV 1/5] END learning_rate=0.01, max_depth=6, n_estimators=100; accuracy: (test=0.800) roc_auc: (test=0.904) total time=   0.7s
# [CV 2/5] END learning_rate=0.01, max_depth=6, n_estimators=100; accuracy: (test=0.892) roc_auc: (test=0.971) total time=   0.6s
# [CV 3/5] END learning_rate=0.01, max_depth=6, n_estimators=100; accuracy: (test=0.885) roc_auc: (test=0.963) total time=   0.7s
# [CV 4/5] END learning_rate=0.01, max_depth=6, n_estimators=100; accuracy: (test=0.913) roc_auc: (test=0.975) total time=   0.7s
# [CV 5/5] END learning_rate=0.01, max_depth=6, n_estimators=100; accuracy: (test=0.887) roc_auc: (test=0.974) total time=   0.7s
# [CV 1/5] END learning_rate=0.01, max_depth=6, n_estimators=500; accuracy: (test=0.772) roc_auc: (test=0.939) total time=   3.2s
# [CV 2/5] END learning_rate=0.01, max_depth=6, n_estimators=500; accuracy: (test=0.948) roc_auc: (test=0.993) total time=   3.0s
# [CV 3/5] END learning_rate=0.01, max_depth=6, n_estimators=500; accuracy: (test=0.949) roc_auc: (test=0.993) total time=   2.9s
# [CV 4/5] END learning_rate=0.01, max_depth=6, n_estimators=500; accuracy: (test=0.951) roc_auc: (test=0.992) total time=   3.1s
# [CV 5/5] END learning_rate=0.01, max_depth=6, n_estimators=500; accuracy: (test=0.936) roc_auc: (test=0.992) total time=   3.2s
# [CV 1/5] END learning_rate=0.01, max_depth=6, n_estimators=1000; accuracy: (test=0.744) roc_auc: (test=0.950) total time=   6.0s
# [CV 2/5] END learning_rate=0.01, max_depth=6, n_estimators=1000; accuracy: (test=0.964) roc_auc: (test=0.995) total time=   5.9s
# [CV 3/5] END learning_rate=0.01, max_depth=6, n_estimators=1000; accuracy: (test=0.951) roc_auc: (test=0.995) total time=   6.1s
# [CV 4/5] END learning_rate=0.01, max_depth=6, n_estimators=1000; accuracy: (test=0.957) roc_auc: (test=0.995) total time=   5.6s
# [CV 5/5] END learning_rate=0.01, max_depth=6, n_estimators=1000; accuracy: (test=0.943) roc_auc: (test=0.995) total time=   5.7s
# [CV 1/5] END learning_rate=0.01, max_depth=10, n_estimators=100; accuracy: (test=0.828) roc_auc: (test=0.921) total time=   1.1s
# [CV 2/5] END learning_rate=0.01, max_depth=10, n_estimators=100; accuracy: (test=0.928) roc_auc: (test=0.983) total time=   1.1s
# [CV 3/5] END learning_rate=0.01, max_depth=10, n_estimators=100; accuracy: (test=0.902) roc_auc: (test=0.974) total time=   1.1s
# [CV 4/5] END learning_rate=0.01, max_depth=10, n_estimators=100; accuracy: (test=0.923) roc_auc: (test=0.980) total time=   1.2s
# [CV 5/5] END learning_rate=0.01, max_depth=10, n_estimators=100; accuracy: (test=0.908) roc_auc: (test=0.980) total time=   1.2s
# [CV 1/5] END learning_rate=0.01, max_depth=10, n_estimators=500; accuracy: (test=0.805) roc_auc: (test=0.949) total time=   5.3s
# [CV 2/5] END learning_rate=0.01, max_depth=10, n_estimators=500; accuracy: (test=0.957) roc_auc: (test=0.995) total time=   5.3s
# [CV 3/5] END learning_rate=0.01, max_depth=10, n_estimators=500; accuracy: (test=0.943) roc_auc: (test=0.991) total time=   5.4s
# [CV 4/5] END learning_rate=0.01, max_depth=10, n_estimators=500; accuracy: (test=0.954) roc_auc: (test=0.995) total time=   5.6s
# [CV 5/5] END learning_rate=0.01, max_depth=10, n_estimators=500; accuracy: (test=0.944) roc_auc: (test=0.993) total time=   5.4s
# [CV 1/5] END learning_rate=0.01, max_depth=10, n_estimators=1000; accuracy: (test=0.772) roc_auc: (test=0.955) total time=   9.5s
# [CV 2/5] END learning_rate=0.01, max_depth=10, n_estimators=1000; accuracy: (test=0.962) roc_auc: (test=0.996) total time=  11.0s
# [CV 3/5] END learning_rate=0.01, max_depth=10, n_estimators=1000; accuracy: (test=0.952) roc_auc: (test=0.993) total time=  10.2s
# [CV 4/5] END learning_rate=0.01, max_depth=10, n_estimators=1000; accuracy: (test=0.959) roc_auc: (test=0.995) total time=   9.1s
# [CV 5/5] END learning_rate=0.01, max_depth=10, n_estimators=1000; accuracy: (test=0.944) roc_auc: (test=0.994) total time=   9.0s
# [CV 1/5] END learning_rate=0.05, max_depth=3, n_estimators=100; accuracy: (test=0.792) roc_auc: (test=0.907) total time=   0.3s
# [CV 2/5] END learning_rate=0.05, max_depth=3, n_estimators=100; accuracy: (test=0.918) roc_auc: (test=0.979) total time=   0.3s
# [CV 3/5] END learning_rate=0.05, max_depth=3, n_estimators=100; accuracy: (test=0.895) roc_auc: (test=0.976) total time=   0.3s
# [CV 4/5] END learning_rate=0.05, max_depth=3, n_estimators=100; accuracy: (test=0.925) roc_auc: (test=0.979) total time=   0.3s
# [CV 5/5] END learning_rate=0.05, max_depth=3, n_estimators=100; accuracy: (test=0.920) roc_auc: (test=0.981) total time=   0.3s
# [CV 1/5] END learning_rate=0.05, max_depth=3, n_estimators=500; accuracy: (test=0.713) roc_auc: (test=0.932) total time=   1.4s
# [CV 2/5] END learning_rate=0.05, max_depth=3, n_estimators=500; accuracy: (test=0.954) roc_auc: (test=0.995) total time=   1.5s
# [CV 3/5] END learning_rate=0.05, max_depth=3, n_estimators=500; accuracy: (test=0.952) roc_auc: (test=0.993) total time=   1.4s
# [CV 4/5] END learning_rate=0.05, max_depth=3, n_estimators=500; accuracy: (test=0.957) roc_auc: (test=0.993) total time=   1.4s
# [CV 5/5] END learning_rate=0.05, max_depth=3, n_estimators=500; accuracy: (test=0.936) roc_auc: (test=0.995) total time=   1.5s
# [CV 1/5] END learning_rate=0.05, max_depth=3, n_estimators=1000; accuracy: (test=0.685) roc_auc: (test=0.941) total time=   2.6s
# [CV 2/5] END learning_rate=0.05, max_depth=3, n_estimators=1000; accuracy: (test=0.952) roc_auc: (test=0.995) total time=   2.7s
# [CV 3/5] END learning_rate=0.05, max_depth=3, n_estimators=1000; accuracy: (test=0.957) roc_auc: (test=0.994) total time=   2.6s
# [CV 4/5] END learning_rate=0.05, max_depth=3, n_estimators=1000; accuracy: (test=0.961) roc_auc: (test=0.995) total time=   3.0s
# [CV 5/5] END learning_rate=0.05, max_depth=3, n_estimators=1000; accuracy: (test=0.941) roc_auc: (test=0.995) total time=   2.8s
# [CV 1/5] END learning_rate=0.05, max_depth=6, n_estimators=100; accuracy: (test=0.777) roc_auc: (test=0.939) total time=   0.6s
# [CV 2/5] END learning_rate=0.05, max_depth=6, n_estimators=100; accuracy: (test=0.952) roc_auc: (test=0.993) total time=   0.6s
# [CV 3/5] END learning_rate=0.05, max_depth=6, n_estimators=100; accuracy: (test=0.944) roc_auc: (test=0.992) total time=   0.6s
# [CV 4/5] END learning_rate=0.05, max_depth=6, n_estimators=100; accuracy: (test=0.949) roc_auc: (test=0.992) total time=   0.6s
# [CV 5/5] END learning_rate=0.05, max_depth=6, n_estimators=100; accuracy: (test=0.934) roc_auc: (test=0.991) total time=   0.6s
# [CV 1/5] END learning_rate=0.05, max_depth=6, n_estimators=500; accuracy: (test=0.716) roc_auc: (test=0.956) total time=   2.7s
# [CV 2/5] END learning_rate=0.05, max_depth=6, n_estimators=500; accuracy: (test=0.962) roc_auc: (test=0.995) total time=   2.9s
# [CV 3/5] END learning_rate=0.05, max_depth=6, n_estimators=500; accuracy: (test=0.952) roc_auc: (test=0.996) total time=   2.9s
# [CV 4/5] END learning_rate=0.05, max_depth=6, n_estimators=500; accuracy: (test=0.967) roc_auc: (test=0.996) total time=   2.9s
# [CV 5/5] END learning_rate=0.05, max_depth=6, n_estimators=500; accuracy: (test=0.944) roc_auc: (test=0.995) total time=   2.9s
# [CV 1/5] END learning_rate=0.05, max_depth=6, n_estimators=1000; accuracy: (test=0.726) roc_auc: (test=0.959) total time=   4.6s
# [CV 2/5] END learning_rate=0.05, max_depth=6, n_estimators=1000; accuracy: (test=0.964) roc_auc: (test=0.995) total time=   5.1s
# [CV 3/5] END learning_rate=0.05, max_depth=6, n_estimators=1000; accuracy: (test=0.954) roc_auc: (test=0.995) total time=   4.8s
# [CV 4/5] END learning_rate=0.05, max_depth=6, n_estimators=1000; accuracy: (test=0.969) roc_auc: (test=0.997) total time=   5.7s
# [CV 5/5] END learning_rate=0.05, max_depth=6, n_estimators=1000; accuracy: (test=0.944) roc_auc: (test=0.994) total time=   5.2s
# [CV 1/5] END learning_rate=0.05, max_depth=10, n_estimators=100; accuracy: (test=0.800) roc_auc: (test=0.949) total time=   1.0s
# [CV 2/5] END learning_rate=0.05, max_depth=10, n_estimators=100; accuracy: (test=0.959) roc_auc: (test=0.995) total time=   1.1s
# [CV 3/5] END learning_rate=0.05, max_depth=10, n_estimators=100; accuracy: (test=0.949) roc_auc: (test=0.991) total time=   1.0s
# [CV 4/5] END learning_rate=0.05, max_depth=10, n_estimators=100; accuracy: (test=0.954) roc_auc: (test=0.995) total time=   1.2s
# [CV 5/5] END learning_rate=0.05, max_depth=10, n_estimators=100; accuracy: (test=0.939) roc_auc: (test=0.993) total time=   1.0s
# [CV 1/5] END learning_rate=0.05, max_depth=10, n_estimators=500; accuracy: (test=0.767) roc_auc: (test=0.958) total time=   3.4s
# [CV 2/5] END learning_rate=0.05, max_depth=10, n_estimators=500; accuracy: (test=0.967) roc_auc: (test=0.996) total time=   3.9s
# [CV 3/5] END learning_rate=0.05, max_depth=10, n_estimators=500; accuracy: (test=0.959) roc_auc: (test=0.993) total time=   4.0s
# [CV 4/5] END learning_rate=0.05, max_depth=10, n_estimators=500; accuracy: (test=0.964) roc_auc: (test=0.996) total time=   3.7s
# [CV 5/5] END learning_rate=0.05, max_depth=10, n_estimators=500; accuracy: (test=0.944) roc_auc: (test=0.994) total time=   3.8s
# [CV 1/5] END learning_rate=0.05, max_depth=10, n_estimators=1000; accuracy: (test=0.756) roc_auc: (test=0.959) total time=   4.9s
# [CV 2/5] END learning_rate=0.05, max_depth=10, n_estimators=1000; accuracy: (test=0.969) roc_auc: (test=0.996) total time=   6.8s
# [CV 3/5] END learning_rate=0.05, max_depth=10, n_estimators=1000; accuracy: (test=0.957) roc_auc: (test=0.993) total time=   6.9s
# [CV 4/5] END learning_rate=0.05, max_depth=10, n_estimators=1000; accuracy: (test=0.959) roc_auc: (test=0.996) total time=   7.0s
# [CV 5/5] END learning_rate=0.05, max_depth=10, n_estimators=1000; accuracy: (test=0.944) roc_auc: (test=0.993) total time=   6.1s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=100; accuracy: (test=0.779) roc_auc: (test=0.920) total time=   0.3s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=100; accuracy: (test=0.936) roc_auc: (test=0.988) total time=   0.2s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=100; accuracy: (test=0.934) roc_auc: (test=0.989) total time=   0.3s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=100; accuracy: (test=0.941) roc_auc: (test=0.987) total time=   0.2s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=100; accuracy: (test=0.926) roc_auc: (test=0.988) total time=   0.3s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=500; accuracy: (test=0.690) roc_auc: (test=0.937) total time=   1.2s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=500; accuracy: (test=0.948) roc_auc: (test=0.995) total time=   1.2s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=500; accuracy: (test=0.959) roc_auc: (test=0.995) total time=   1.1s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=500; accuracy: (test=0.961) roc_auc: (test=0.995) total time=   1.0s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=500; accuracy: (test=0.944) roc_auc: (test=0.994) total time=   1.4s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=1000; accuracy: (test=0.692) roc_auc: (test=0.942) total time=   2.8s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=1000; accuracy: (test=0.952) roc_auc: (test=0.994) total time=   2.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=1000; accuracy: (test=0.959) roc_auc: (test=0.995) total time=   2.9s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=1000; accuracy: (test=0.959) roc_auc: (test=0.996) total time=   2.8s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=1000; accuracy: (test=0.946) roc_auc: (test=0.991) total time=   2.9s
# [CV 1/5] END learning_rate=0.1, max_depth=6, n_estimators=100; accuracy: (test=0.766) roc_auc: (test=0.947) total time=   0.5s
# [CV 2/5] END learning_rate=0.1, max_depth=6, n_estimators=100; accuracy: (test=0.959) roc_auc: (test=0.995) total time=   0.6s
# [CV 3/5] END learning_rate=0.1, max_depth=6, n_estimators=100; accuracy: (test=0.951) roc_auc: (test=0.994) total time=   0.7s
# [CV 4/5] END learning_rate=0.1, max_depth=6, n_estimators=100; accuracy: (test=0.959) roc_auc: (test=0.995) total time=   0.6s
# [CV 5/5] END learning_rate=0.1, max_depth=6, n_estimators=100; accuracy: (test=0.946) roc_auc: (test=0.995) total time=   0.6s
# [CV 1/5] END learning_rate=0.1, max_depth=6, n_estimators=500; accuracy: (test=0.730) roc_auc: (test=0.958) total time=   2.5s
# [CV 2/5] END learning_rate=0.1, max_depth=6, n_estimators=500; accuracy: (test=0.964) roc_auc: (test=0.995) total time=   2.8s
# [CV 3/5] END learning_rate=0.1, max_depth=6, n_estimators=500; accuracy: (test=0.956) roc_auc: (test=0.995) total time=   2.7s
# [CV 4/5] END learning_rate=0.1, max_depth=6, n_estimators=500; accuracy: (test=0.962) roc_auc: (test=0.996) total time=   2.6s
# [CV 5/5] END learning_rate=0.1, max_depth=6, n_estimators=500; accuracy: (test=0.943) roc_auc: (test=0.994) total time=   2.7s
# [CV 1/5] END learning_rate=0.1, max_depth=6, n_estimators=1000; accuracy: (test=0.721) roc_auc: (test=0.958) total time=   4.0s
# [CV 2/5] END learning_rate=0.1, max_depth=6, n_estimators=1000; accuracy: (test=0.962) roc_auc: (test=0.994) total time=   5.2s
# [CV 3/5] END learning_rate=0.1, max_depth=6, n_estimators=1000; accuracy: (test=0.954) roc_auc: (test=0.995) total time=   5.0s
# [CV 4/5] END learning_rate=0.1, max_depth=6, n_estimators=1000; accuracy: (test=0.964) roc_auc: (test=0.996) total time=   5.1s
# [CV 5/5] END learning_rate=0.1, max_depth=6, n_estimators=1000; accuracy: (test=0.949) roc_auc: (test=0.993) total time=   5.0s
# [CV 1/5] END learning_rate=0.1, max_depth=10, n_estimators=100; accuracy: (test=0.774) roc_auc: (test=0.954) total time=   0.9s
# [CV 2/5] END learning_rate=0.1, max_depth=10, n_estimators=100; accuracy: (test=0.969) roc_auc: (test=0.996) total time=   1.0s
# [CV 3/5] END learning_rate=0.1, max_depth=10, n_estimators=100; accuracy: (test=0.946) roc_auc: (test=0.993) total time=   1.0s
# [CV 4/5] END learning_rate=0.1, max_depth=10, n_estimators=100; accuracy: (test=0.959) roc_auc: (test=0.995) total time=   1.0s
# [CV 5/5] END learning_rate=0.1, max_depth=10, n_estimators=100; accuracy: (test=0.941) roc_auc: (test=0.992) total time=   1.0s
# [CV 1/5] END learning_rate=0.1, max_depth=10, n_estimators=500; accuracy: (test=0.761) roc_auc: (test=0.958) total time=   2.7s
# [CV 2/5] END learning_rate=0.1, max_depth=10, n_estimators=500; accuracy: (test=0.966) roc_auc: (test=0.996) total time=   3.5s
# [CV 3/5] END learning_rate=0.1, max_depth=10, n_estimators=500; accuracy: (test=0.957) roc_auc: (test=0.994) total time=   3.5s
# [CV 4/5] END learning_rate=0.1, max_depth=10, n_estimators=500; accuracy: (test=0.962) roc_auc: (test=0.995) total time=   3.5s
# [CV 5/5] END learning_rate=0.1, max_depth=10, n_estimators=500; accuracy: (test=0.941) roc_auc: (test=0.992) total time=   3.4s
# [CV 1/5] END learning_rate=0.1, max_depth=10, n_estimators=1000; accuracy: (test=0.754) roc_auc: (test=0.958) total time=   4.2s
# [CV 2/5] END learning_rate=0.1, max_depth=10, n_estimators=1000; accuracy: (test=0.966) roc_auc: (test=0.995) total time=   5.7s
# [CV 3/5] END learning_rate=0.1, max_depth=10, n_estimators=1000; accuracy: (test=0.956) roc_auc: (test=0.994) total time=   5.7s
# [CV 4/5] END learning_rate=0.1, max_depth=10, n_estimators=1000; accuracy: (test=0.961) roc_auc: (test=0.996) total time=   5.9s
# [CV 5/5] END learning_rate=0.1, max_depth=10, n_estimators=1000; accuracy: (test=0.943) roc_auc: (test=0.992) total time=   5.6s
# [CV 1/5] END learning_rate=0.3, max_depth=3, n_estimators=100; accuracy: (test=0.695) roc_auc: (test=0.931) total time=   0.3s
# [CV 2/5] END learning_rate=0.3, max_depth=3, n_estimators=100; accuracy: (test=0.951) roc_auc: (test=0.995) total time=   0.3s
# [CV 3/5] END learning_rate=0.3, max_depth=3, n_estimators=100; accuracy: (test=0.961) roc_auc: (test=0.992) total time=   0.3s
# [CV 4/5] END learning_rate=0.3, max_depth=3, n_estimators=100; accuracy: (test=0.959) roc_auc: (test=0.994) total time=   0.3s
# [CV 5/5] END learning_rate=0.3, max_depth=3, n_estimators=100; accuracy: (test=0.948) roc_auc: (test=0.994) total time=   0.3s
# [CV 1/5] END learning_rate=0.3, max_depth=3, n_estimators=500; accuracy: (test=0.679) roc_auc: (test=0.940) total time=   1.3s
# [CV 2/5] END learning_rate=0.3, max_depth=3, n_estimators=500; accuracy: (test=0.954) roc_auc: (test=0.994) total time=   1.2s
# [CV 3/5] END learning_rate=0.3, max_depth=3, n_estimators=500; accuracy: (test=0.962) roc_auc: (test=0.995) total time=   1.2s
# [CV 4/5] END learning_rate=0.3, max_depth=3, n_estimators=500; accuracy: (test=0.954) roc_auc: (test=0.996) total time=   1.4s
# [CV 5/5] END learning_rate=0.3, max_depth=3, n_estimators=500; accuracy: (test=0.948) roc_auc: (test=0.991) total time=   1.4s
# [CV 1/5] END learning_rate=0.3, max_depth=3, n_estimators=1000; accuracy: (test=0.675) roc_auc: (test=0.937) total time=   2.6s
# [CV 2/5] END learning_rate=0.3, max_depth=3, n_estimators=1000; accuracy: (test=0.949) roc_auc: (test=0.994) total time=   2.9s
# [CV 3/5] END learning_rate=0.3, max_depth=3, n_estimators=1000; accuracy: (test=0.964) roc_auc: (test=0.995) total time=   2.8s
# [CV 4/5] END learning_rate=0.3, max_depth=3, n_estimators=1000; accuracy: (test=0.951) roc_auc: (test=0.996) total time=   2.9s
# [CV 5/5] END learning_rate=0.3, max_depth=3, n_estimators=1000; accuracy: (test=0.941) roc_auc: (test=0.990) total time= 1.3min
# [CV 1/5] END learning_rate=0.3, max_depth=6, n_estimators=100; accuracy: (test=0.749) roc_auc: (test=0.955) total time=   0.5s
# [CV 2/5] END learning_rate=0.3, max_depth=6, n_estimators=100; accuracy: (test=0.961) roc_auc: (test=0.996) total time=   0.5s
# [CV 3/5] END learning_rate=0.3, max_depth=6, n_estimators=100; accuracy: (test=0.948) roc_auc: (test=0.995) total time=   0.5s
# [CV 4/5] END learning_rate=0.3, max_depth=6, n_estimators=100; accuracy: (test=0.966) roc_auc: (test=0.996) total time=   0.7s
# [CV 5/5] END learning_rate=0.3, max_depth=6, n_estimators=100; accuracy: (test=0.948) roc_auc: (test=0.994) total time=   0.5s
# [CV 1/5] END learning_rate=0.3, max_depth=6, n_estimators=500; accuracy: (test=0.736) roc_auc: (test=0.957) total time=   1.8s
# [CV 2/5] END learning_rate=0.3, max_depth=6, n_estimators=500; accuracy: (test=0.959) roc_auc: (test=0.996) total time=   2.2s
# [CV 3/5] END learning_rate=0.3, max_depth=6, n_estimators=500; accuracy: (test=0.949) roc_auc: (test=0.996) total time=   1.9s
# [CV 4/5] END learning_rate=0.3, max_depth=6, n_estimators=500; accuracy: (test=0.962) roc_auc: (test=0.996) total time=   1.9s
# [CV 5/5] END learning_rate=0.3, max_depth=6, n_estimators=500; accuracy: (test=0.951) roc_auc: (test=0.993) total time=   2.3s
# [CV 1/5] END learning_rate=0.3, max_depth=6, n_estimators=1000; accuracy: (test=0.726) roc_auc: (test=0.957) total time=   2.7s
# [CV 2/5] END learning_rate=0.3, max_depth=6, n_estimators=1000; accuracy: (test=0.957) roc_auc: (test=0.996) total time=   4.2s
# [CV 3/5] END learning_rate=0.3, max_depth=6, n_estimators=1000; accuracy: (test=0.949) roc_auc: (test=0.996) total time=   4.1s
# [CV 4/5] END learning_rate=0.3, max_depth=6, n_estimators=1000; accuracy: (test=0.961) roc_auc: (test=0.996) total time=   4.3s
# [CV 5/5] END learning_rate=0.3, max_depth=6, n_estimators=1000; accuracy: (test=0.951) roc_auc: (test=0.993) total time=   4.0s
# [CV 1/5] END learning_rate=0.3, max_depth=10, n_estimators=100; accuracy: (test=0.779) roc_auc: (test=0.957) total time=   0.7s
# [CV 2/5] END learning_rate=0.3, max_depth=10, n_estimators=100; accuracy: (test=0.962) roc_auc: (test=0.995) total time=   0.8s
# [CV 3/5] END learning_rate=0.3, max_depth=10, n_estimators=100; accuracy: (test=0.949) roc_auc: (test=0.994) total time=   0.8s
# [CV 4/5] END learning_rate=0.3, max_depth=10, n_estimators=100; accuracy: (test=0.967) roc_auc: (test=0.995) total time=   0.7s
# [CV 5/5] END learning_rate=0.3, max_depth=10, n_estimators=100; accuracy: (test=0.946) roc_auc: (test=0.992) total time=   0.7s
# [CV 1/5] END learning_rate=0.3, max_depth=10, n_estimators=500; accuracy: (test=0.762) roc_auc: (test=0.956) total time=   1.7s
# [CV 2/5] END learning_rate=0.3, max_depth=10, n_estimators=500; accuracy: (test=0.962) roc_auc: (test=0.995) total time=   2.6s
# [CV 3/5] END learning_rate=0.3, max_depth=10, n_estimators=500; accuracy: (test=0.956) roc_auc: (test=0.995) total time=   2.6s
# [CV 4/5] END learning_rate=0.3, max_depth=10, n_estimators=500; accuracy: (test=0.962) roc_auc: (test=0.996) total time=   2.6s
# [CV 5/5] END learning_rate=0.3, max_depth=10, n_estimators=500; accuracy: (test=0.941) roc_auc: (test=0.993) total time=   2.5s
# [CV 1/5] END learning_rate=0.3, max_depth=10, n_estimators=1000; accuracy: (test=0.754) roc_auc: (test=0.955) total time=   2.8s
# [CV 2/5] END learning_rate=0.3, max_depth=10, n_estimators=1000; accuracy: (test=0.964) roc_auc: (test=0.995) total time=   4.3s
# [CV 3/5] END learning_rate=0.3, max_depth=10, n_estimators=1000; accuracy: (test=0.954) roc_auc: (test=0.995) total time=   4.4s
# [CV 4/5] END learning_rate=0.3, max_depth=10, n_estimators=1000; accuracy: (test=0.962) roc_auc: (test=0.996) total time=   4.4s
# [CV 5/5] END learning_rate=0.3, max_depth=10, n_estimators=1000; accuracy: (test=0.944) roc_auc: (test=0.992) total time=   4.2s
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                      callbacks=None, colsample_bylevel=1,
#                                      colsample_bynode=1, colsample_bytree=1,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=0, gpu_id=-1,
#                                      grow_policy='depthwise',
#                                      importance_type=None,
#                                      interaction_constraints='',
#                                      learning_rate=0.05, max_bi...
#                                      max_cat_threshold=64, max_cat_to_onehot=4,
#                                      max_delta_step=0, max_depth=10,
#                                      max_leaves=0, min_child_weight=1,
#                                      missing=nan, monotone_constraints='()',
#                                      n_estimators=1000, n_jobs=0,
#                                      num_parallel_tree=1, predictor='auto',
#                                      random_state=42, ...),
#              param_grid={'learning_rate': [0.01, 0.05, 0.1, 0.3],
#                          'max_depth': [3, 6, 10],
#                          'n_estimators': [100, 500, 1000]},
#              refit='roc_auc', scoring=['roc_auc', 'accuracy'], verbose=4)

# %%
print(GS.best_estimator_, '\n', GS.best_score_)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.05, max_bin=256,
#               max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#               max_depth=6, max_leaves=0, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=1000, n_jobs=0,
#               num_parallel_tree=1, predictor='auto', random_state=42, ...)
#  0.9879957000806237

# %%
def metric_calc(model_list, X_test_scaled, y_test):
    for elem in model_list:
        print(str(elem))
        model_predictions = elem.predict(X_test_scaled)
        print("Training Accuracy: " + str(elem.score(X_train_scaled, y_train)))
        print("Test Accuracy: " + str(accuracy_score(y_test, model_predictions)))
        print("AUC Score: " + str(roc_auc_score(y_test, model_predictions)))
        print(classification_report(y_test, model_predictions))

# %%
metric_calc(model_list, X_test_scaled, y_test)
# Out:
# LogisticRegression()
# Training Accuracy: 0.8095081967213115
# Test Accuracy: 0.7767857142857143
# AUC Score: 0.7457593920162965
#               precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86       381
#            1       0.37      0.70      0.48        67
#
#     accuracy                           0.78       448
#    macro avg       0.65      0.75      0.67       448
# weighted avg       0.85      0.78      0.80       448
#
# DecisionTreeClassifier()
# Training Accuracy: 0.9957377049180328
# Test Accuracy: 0.7946428571428571
# AUC Score: 0.6640028205429546
#               precision    recall  f1-score   support
#
#            0       0.90      0.85      0.88       381
#            1       0.36      0.48      0.41        67
#
#     accuracy                           0.79       448
#    macro avg       0.63      0.66      0.64       448
# weighted avg       0.82      0.79      0.81       448
#
# RandomForestClassifier()
# Training Accuracy: 0.9957377049180328
# Test Accuracy: 0.8794642857142857
# AUC Score: 0.7323226387746308
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93       381
#            1       0.61      0.52      0.56        67
#
#     accuracy                           0.88       448
#    macro avg       0.77      0.73      0.75       448
# weighted avg       0.87      0.88      0.88       448
#
# KNeighborsClassifier(n_neighbors=20)
# Training Accuracy: 0.8324590163934427
# Test Accuracy: 0.7276785714285714
# AUC Score: 0.716888000940181
#               precision    recall  f1-score   support
#
#            0       0.93      0.73      0.82       381
#            1       0.32      0.70      0.44        67
#
#     accuracy                           0.73       448
#    macro avg       0.62      0.72      0.63       448
# weighted avg       0.84      0.73      0.76       448
#
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.05, max_bin=256,
#               max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#               max_depth=6, max_leaves=0, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=1000, n_jobs=0,
#               num_parallel_tree=1, predictor='auto', random_state=42, ...)
# Training Accuracy: 0.9957377049180328
# Test Accuracy: 0.890625
# AUC Score: 0.7265836173463391
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94       381
#            1       0.69      0.49      0.57        67
#
#     accuracy                           0.89       448
#    macro avg       0.80      0.73      0.76       448
# weighted avg       0.88      0.89      0.88       448
